# %%
import google.generativeai as genai

print("Gemini installed successfully!")
# Out:
# Gemini installed successfully!
# C:\Users\Dell\AppData\Local\Temp\ipykernel_4816\2676244363.py:1: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai

# %%
# !pip install -U google-genai

# %%
from google import genai

print("New Gemini SDK installed successfully!")
# Out:
# New Gemini SDK installed successfully!

# %%
from google import genai

client = genai.Client(api_key="from google studio, your API key")

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="What is Artificial Intelligence?"
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[5], line 5
#       1 from google import genai
#       2
#       3 client = genai.Client(api_key="from google studio, your API key")
#       4
# ----> 5 response = client.models.generate_content(
#       6     model="gemini-2.5-flash",
#       7     contents="What is Artificial Intelligence?"
#       8 )
#
# File ~\anaconda3\envs\llm-roadmap\Lib\site-packages\google\genai\models.py:6526, in Models.generate_content(self, model, contents, config)
#    6522   parsed_config_to_call = _extra_utils.get_usage_header(
#    6523       parsed_config_to_call
#    6524   )
#    6525 i += 1
# -> 6526 response = self._generate_content(
#    6527     model=model, contents=contents, config=parsed_config_to_call
#    6528 )
#    6530 if not function_map:
#    6531   break
#
# ...

# %%
queries = [
    "Summarize the concept of Machine Learning in 3 lines.",

    "Explain RAG to a beginner.",

    "What is the difference between BERT and GPT?",

    "Write Python code to reverse a string.",

    "Explain FAISS in simple words."]

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents = queries
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[3], line 12
#       8     "Write Python code to reverse a string.",
#       9
#      10     "Explain FAISS in simple words."]
#      11
# ---> 12 response = client.models.generate_content(
#      13     model="gemini-2.5-flash",
#      14     contents = queries
#      15 )
#
# File ~\anaconda3\envs\llm-roadmap\Lib\site-packages\google\genai\models.py:6526, in Models.generate_content(self, model, contents, config)
#    6522   parsed_config_to_call = _extra_utils.get_usage_header(
#    6523       parsed_config_to_call
#    6524   )
#    6525 i += 1
# -> 6526 response = self._generate_content(
#    6527     model=model, contents=contents, config=parsed_config_to_call
#    6528 )
#    6530 if not function_map:
#    6531   break
#
# ...

# %%
queries = [
    "Summarize the concept of Machine Learning in 3 lines.",
    "Explain RAG to a beginner.",
    "What is the difference between BERT and GPT?",
    "Write Python code to reverse a string.",
    "Explain FAISS in simple words."
]

for query in queries:
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=query
    )

    print(f"\nQuestion: {query}")
    print(response.text)
    print("-" * 70)
# Out:
# Question: Summarize the concept of Machine Learning in 3 lines.
# Machine Learning empowers systems to learn from data and improve performance over time, rather than being explicitly programmed. It uses algorithms to identify patterns, make predictions, or classify information based on examples. This enables computers to automate complex tasks, gain insights, and make intelligent decisions in various applications.
# ----------------------------------------------------------------------
#
# Question: Explain RAG to a beginner.
# Imagine you have a super-smart assistant (that's the **Large Language Model** or LLM, like ChatGPT). This assistant is brilliant at writing, summarizing, and sounding human. However, it has two main limitations:
#
# 1.  **It's only as smart as its training data:** Its knowledge cutoff might be a year or two ago, so it doesn't know about the latest news, your company's newest policies, or your personal notes.
# ...

# %% [markdown]
# # Day 11 Summary – Introduction to LLM APIs (Google Gemini)
#
# ## Objective
# Learn how to connect to a Large Language Model (LLM) using the Google Gemini API and generate AI-powered responses.
#
# ## Topics Covered
# - What is an LLM?
# - Google AI Studio
# - Creating a Gemini API Key
# - Google GenAI SDK (`google-genai`)
# - Making the first API call
# - Sending prompts to Gemini
# - Understanding AI-generated responses
#
# ## Practical Work
# - Created a Google Gemini API Key.
# - Installed the latest `google-genai` package.
# - Connected Python with the Gemini API.
# - Successfully generated responses using `gemini-2.5-flash`.
# - Learned that `google.generativeai` is deprecated and replaced by the new `google-genai` SDK.
#
# ## Assignment Completed
# Tested Gemini using the following prompts:
# - Summarize Machine Learning
# - Explain RAG
# - Difference between BERT and GPT
# - Reverse a string in Python
# - Explain FAISS
#
# Gemini successfully answered all prompts.
#
# ## Key Learning
# LLMs can generate intelligent responses from natural language prompts. APIs allow us to integrate these models into our own applications, making it possible to build chatbots, assistants, and AI-powered systems.
#
# Day 11 Completed Successfully

# %%
from google import genai
client = genai.Client(api_key="from google studionyour API key")

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="""
You are an AI teacher.

Rules:
- i am giving you multiple questions.
- Each Answer will be in less than 150 words
- Use simple English.
- Give only the answer.

Questions:
What is a Retriever?
How LangChain retrieves relevant documents
Passing retrieved context to an LLM
Building a complete RAG pipeline
Understanding why RAG produces better answers than using an LLM alone
"""
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[4], line 4
#       1 from google import genai
#       2 client = genai.Client(api_key="your API key")
#       3
# ----> 4 response = client.models.generate_content(
#       5     model="gemini-2.5-flash",
#       6     contents="""
#       7 You are an AI teacher.
#
# File ~\anaconda3\envs\llm-roadmap\Lib\site-packages\google\genai\models.py:6526, in Models.generate_content(self, model, contents, config)
#    6522   parsed_config_to_call = _extra_utils.get_usage_header(
#    6523       parsed_config_to_call
#    6524   )
#    6525 i += 1
# -> 6526 response = self._generate_content(
#    6527     model=model, contents=contents, config=parsed_config_to_call
#    6528 )
#    6530 if not function_map:
#    6531   break
#
# ...
